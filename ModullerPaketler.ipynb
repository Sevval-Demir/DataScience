# %%
import numpy as np
import matplotlib.pyplot as matplot

# %%
maasListesi=numpy.random.normal(4000,500,1000)

# %%
numpy.mean(maasListesi)
#rastgele ürettiği için değerler farklı çıkar
# Out:
# 4016.3080277812405

# %%
matplot.hist(maasListesi,100)
matplot.show()
